# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
data = pd.read_csv('Spotify_final_dataset.csv')
data
# Out:
#        Position         Artist Name  \
# 0             1        Post Malone
# 1             2         Juice WRLD
# 2             3       Lil Uzi Vert
# 3             4            J. Cole
# 4             5        Post Malone
# ...         ...                 ...
# 11079     11080     The Band Perry
# 11080     11081  Justin Timberlake
# 11081     11082      Mike WiLL Made
# 11082     11083          The Vamps
# 11083     11084                 JAY
#
#                                         Song Name  Days  Top 10 (xTimes)  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse  1506            302.0
# 1                                    Lucid Dreams  1673            178.0
# 2                                   XO TOUR Llif3  1853            212.0
# 3                                  No Role Modelz  2547              6.0
# 4                                        rockstar  1223            186.0
# ...                                           ...   ...              ...
# 11079                              If I Die Young     1              0.0
# 11080                             Not a Bad Thing     1              0.0
# 11081                                      It  23     1              0.0
# 11082                             Somebody To You     1              0.0
# 11083                               Z  Holy Grail     1              0.0
#
#        Peak Position Peak Position (xTimes)  Peak Streams  Total Streams
# 0                  1                  (x29)       2118242      883369738
# 1                  1                  (x20)       2127668      864832399
# 2                  1                   (x4)       1660502      781153024
# 3                  7                      0        659366      734857487
# 4                  1                 (x124)       2905678      718865961
# ...              ...                    ...           ...            ...
# 11079            184                      0         51321          51321
# 11080            196                      0         49512          49512
# 11081            167                      0         46547          46547
# 11082            200                      0         44962          44962
# 11083            184                      0         44323          44323
#
# [11084 rows x 9 columns]

# %%
columns_to_drop = ['Position', 'Days', 'Top 10 (xTimes)', 'Peak Position', 'Peak Position (xTimes)', 'Peak Streams', 'Total Streams']
data.drop(columns=columns_to_drop, inplace=True)

# %%
data
# Out:
#               Artist Name                                   Song Name
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2           Lil Uzi Vert                                XO TOUR Llif3
# 3                J. Cole                               No Role Modelz
# 4            Post Malone                                     rockstar
# ...                   ...                                         ...
# 11079     The Band Perry                               If I Die Young
# 11080  Justin Timberlake                              Not a Bad Thing
# 11081      Mike WiLL Made                                      It  23
# 11082          The Vamps                              Somebody To You
# 11083                 JAY                               Z  Holy Grail
#
# [11084 rows x 2 columns]

# %%
hot_songs = pd.read_csv('hot_songs.csv')
hot_songs
# Out:
#                                 Title                                 Artists
# 0   Rockin' Around The Christmas Tree                              Brenda Lee
# 1     All I Want For Christmas Is You                            Mariah Carey
# 2                    Jingle Bell Rock                             Bobby Helms
# 3                      Last Christmas                                   Wham!
# 4             A Holly Jolly Christmas                               Burl Ives
# ..                                ...                                     ...
# 95                 El Amor de Su Vida            Grupo Frontera & Grupo Firme
# 96               Standing Next To You                               Jung Kook
# 97                     Man Made A Bar     Morgan Wallen Featuring Eric Church
# 98                           Que Onda  Calle 24 x Chino Pacas x Fuerza Regida
# 99                       Great Gatsby                                Rod Wave
#
# [100 rows x 2 columns]

# %%
data = data.rename(columns={'Artist Name': 'Artists', 'Song Name': 'Title'})
data
# Out:
#                   Artists                                       Title
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2           Lil Uzi Vert                                XO TOUR Llif3
# 3                J. Cole                               No Role Modelz
# 4            Post Malone                                     rockstar
# ...                   ...                                         ...
# 11079     The Band Perry                               If I Die Young
# 11080  Justin Timberlake                              Not a Bad Thing
# 11081      Mike WiLL Made                                      It  23
# 11082          The Vamps                              Somebody To You
# 11083                 JAY                               Z  Holy Grail
#
# [11084 rows x 2 columns]

# %%
data.dtypes
# Out:
# Artists    object
# Title      object
# dtype: object

# %%
data.isna().sum()
# Out:
# Artists    0
# Title      4
# dtype: int64

# %%
data.dropna(subset=['Title'], inplace=True)

# %%
data
# Out:
#                   Artists                                       Title
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2           Lil Uzi Vert                                XO TOUR Llif3
# 3                J. Cole                               No Role Modelz
# 4            Post Malone                                     rockstar
# ...                   ...                                         ...
# 11079     The Band Perry                               If I Die Young
# 11080  Justin Timberlake                              Not a Bad Thing
# 11081      Mike WiLL Made                                      It  23
# 11082          The Vamps                              Somebody To You
# 11083                 JAY                               Z  Holy Grail
#
# [11080 rows x 2 columns]

# %%
def duplicate_remover(df: pd.DataFrame) -> pd.DataFrame:
   
    df2 = df.copy()
    df2 = df2.drop_duplicates()
    return df2

data=duplicate_remover(data)
data
# Out:
#                   Artists                                       Title
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2           Lil Uzi Vert                                XO TOUR Llif3
# 3                J. Cole                               No Role Modelz
# 4            Post Malone                                     rockstar
# ...                   ...                                         ...
# 11079     The Band Perry                               If I Die Young
# 11080  Justin Timberlake                              Not a Bad Thing
# 11081      Mike WiLL Made                                      It  23
# 11082          The Vamps                              Somebody To You
# 11083                 JAY                               Z  Holy Grail
#
# [10941 rows x 2 columns]

# %%
data['Artists_lower'] = data['Artists'].str.lower()
data['Title_lower'] = data['Title'].str.lower()
hot_songs['Artists_lower'] = hot_songs['Artists'].str.lower()
hot_songs['Title_lower'] = hot_songs['Title'].str.lower()

# %%
filtered_data = data[~((data['Artists_lower'].isin(hot_songs['Artists_lower'])) & (data['Title_lower'].isin(hot_songs['Title_lower'])))]
filtered_data = filtered_data.drop(['Artists_lower', 'Title_lower'], axis=1).reset_index(drop=True)
filtered_data
# Out:
#                   Artists                                       Title
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2           Lil Uzi Vert                                XO TOUR Llif3
# 3                J. Cole                               No Role Modelz
# 4            Post Malone                                     rockstar
# ...                   ...                                         ...
# 10936     The Band Perry                               If I Die Young
# 10937  Justin Timberlake                              Not a Bad Thing
# 10938      Mike WiLL Made                                      It  23
# 10939          The Vamps                              Somebody To You
# 10940                 JAY                               Z  Holy Grail
#
# [10941 rows x 2 columns]

# %%
data
# Out:
#                   Artists                                       Title  \
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2           Lil Uzi Vert                                XO TOUR Llif3
# 3                J. Cole                               No Role Modelz
# 4            Post Malone                                     rockstar
# ...                   ...                                         ...
# 11079     The Band Perry                               If I Die Young
# 11080  Justin Timberlake                              Not a Bad Thing
# 11081      Mike WiLL Made                                      It  23
# 11082          The Vamps                              Somebody To You
# 11083                 JAY                               Z  Holy Grail
#
#             Artists_lower                                 Title_lower
# 0            post malone   sunflower  spiderman: into the spiderverse
# 1             juice wrld                                 lucid dreams
# 2           lil uzi vert                                xo tour llif3
# 3                j. cole                               no role modelz
# 4            post malone                                     rockstar
# ...                   ...                                         ...
# 11079     the band perry                               if i die young
# 11080  justin timberlake                              not a bad thing
# 11081      mike will made                                      it  23
# 11082          the vamps                              somebody to you
# 11083                 jay                               z  holy grail
#
# [10941 rows x 4 columns]

# %% [markdown]
# #### There is no hot songs in the dataset

# %%
data=filtered_data.sample(2500)
data=data.reset_index()
data
# Out:
#       index            Artists              Title
# 0      7004     Marvin Divine   Barely Legal 2021
# 1      4265         Bad Bunny     MALDITA POBREZA
# 2       201        Dan + Shay             Tequila
# 3      4826            Eminem           Remind Me
# 4       698       Eartha Kitt          Santa Baby
# ...     ...                ...                ...
# 2495   8420          Gorillaz             Momentz
# 2496   7105      Lana Del Rey               Freak
# 2497   9771       Kodak Black         Let Me Know
# 2498   4234  Childish Gambino             V. 3005
# 2499   5848      Rich The Kid            4 Phones
#
# [2500 rows x 3 columns]

# %%
#data.to_csv("not_hot_songs.csv")
